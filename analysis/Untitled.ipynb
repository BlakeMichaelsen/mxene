# %%
import gspread

# %%
new_file = "first_file_test.txt"
x=57
y=3

# %%
with open(new_file, "w") as f:
    f.write(str(5) + '\n')
    f.write(str(3) + '\n')
    f.write(str(9) + '\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 2
#       1 with open(new_file, "w") as f:
# ----> 2     f.write(int(5) + '\n')
#       3     f.write(str(3) + '\n')
#       4     f.write(str(9) + '\n')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [raw]
# with open("~/mxene/analysis/first_file_test.txt", "r") as f:
#     print(f.read())

# %%
print("g")
# Out:
# g

# %%
with open(new_file) as f:
    for line in f:
        print(line.strip())
# Out:
# 5
# 3
# 9

# %%
with open(new_file, 'r') as f:
    lines = f.readlines()

new_line = str(x/y) + '\n'
lines.insert(1, new_line)

# %%
with open(new_file, 'w') as f:
    f.writelines(lines)

# %%
with open(new_file, 'a') as f:
    f.writelines(str(333))

# %%
with open (new_file, 'r') as f:
    print(f.readlines())
# Out:
# ['5\n', '19.0\n', '3\n', '9\n', '333']
